# %%
import pandas as pd

df = pd.read_csv("../data/players.csv")
test_df = df.head(n = 10)

# %%
len(df['Player'].unique())
# Out:
# 1926

# %%
odds_h = test_df["OddsH"]
odds_a = test_df["OddsA"]
diff_odds = odds_h - odds_a
abs(diff_odds)
# Out:
# 0    3.636694
# 1    1.562868
# 2    1.034029
# 3    2.502377
# 4    6.266214
# 5    1.458614
# 6    0.198956
# 7    2.634977
# 8    1.540149
# 9    0.767542
# dtype: float64

# %%
df[(df['HID'] == 1) & (df['Season'] == 1)]
# Out:
#      Unnamed: 0  Season        Date  HID  AID  N  POFF        Open     OddsH  \
# 17           17       1  1975-11-08    1   17  0     0  1975-11-07  1.492661
# 39           39       1  1975-11-13    1   25  0     0  1975-11-12  1.142846
# 56           56       1  1975-11-15    1   42  0     0  1975-11-14  1.166244
# 64           64       1  1975-11-18    1    4  0     0  1975-11-17  1.144167
# 94           94       1  1975-11-23    1   21  0     0  1975-11-22  1.183352
# 103         103       1  1975-11-25    1   24  0     0  1975-11-24  1.231984
# 112         112       1  1975-11-27    1   12  0     0  1975-11-26  1.292779
# 166         166       1  1975-12-06    1   35  0     0  1975-12-05  1.175611
# 187         187       1  1975-12-11    1   19  0     0  1975-12-10  1.837805
# 201         201       1  1975-12-13    1    2  0     0  1975-12-12  1.336329
# 223         223       1  1975-12-18    1    8  0     0  1975-12-17  1.444159
# ...
